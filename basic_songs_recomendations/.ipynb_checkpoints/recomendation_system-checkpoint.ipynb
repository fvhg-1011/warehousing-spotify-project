# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
from urllib.parse import quote_plus
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from annoy import AnnoyIndex

# %%
# load environment
load_dotenv()
# export env

src_host = os.getenv('SRC_HOST')
src_port = os.getenv('SRC_PORT')
src_dbname = os.getenv('SRC_DBNAME')
src_user = os.getenv('SRC_USER')
src_password = quote_plus(os.getenv('SRC_PASSWORD'))
src_table = os.getenv('SRC_TABLE')

# %%
redshift_url = f"redshift+psycopg2://{src_user}:{src_password}@{src_host}:{src_port}/{src_dbname}?sslmode=disable"

# %%
engine = create_engine(redshift_url)
query = f"SELECT * FROM {src_table};"

# use this for pandas > 2.20
with engine.connect() as conn:
    df = pd.read_sql(
        sql=query,
        con=conn.connection
    )
# Out:
# /tmp/ipykernel_69469/2569432139.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(

# %%
#to shows all features
pd.set_option('display.max_columns',None)

# %%
df[df['track_artist']=="Led Zeppelin"]
# Out:
#                                           track_name  track_artist  \
# 664                             Black Dog - Remaster  Led Zeppelin
# 2075                       Black Dog - 1990 Remaster  Led Zeppelin
# 4111                   Rock and Roll - 1990 Remaster  Led Zeppelin
# 4414                Whole Lotta Love - 1990 Remaster  Led Zeppelin
# 7858                       Ramble On - 1990 Remaster  Led Zeppelin
# 8638                Whole Lotta Love - 1990 Remaster  Led Zeppelin
# 9043            Good Times Bad Times - 1993 Remaster  Led Zeppelin
# 11832                      Immigrant Song - Remaster  Led Zeppelin
# 12102                      Immigrant Song - Remaster  Led Zeppelin
# 12467           Good Times Bad Times - 1993 Remaster  Led Zeppelin
# 12468                        Kashmir - 2012 Remaster  Led Zeppelin
# 12474                      D'yer Mak'er - Remastered  Led Zeppelin
# 12484                      Ramble On - 1990 Remaster  Led Zeppelin
# 17530               Fool in the Rain - 2012 Remaster  Led Zeppelin
# 17573                        Kashmir - 1990 Remaster  Led Zeppelin
# 17576                             Dazed and Confused  Led Zeppelin
# 17577                   Heartbreaker - 1990 Remaster  Led Zeppelin
# 17892                  Stairway to Heaven - Remaster  Led Zeppelin
# 18437          I Can't Quit You Baby - 2014 Remaster  Led Zeppelin
# 18780                  Stairway to Heaven - Remaster  Led Zeppelin
# 20210                  Misty Mountain Hop - Remaster  Led Zeppelin
# 20219                  Rock and Roll - 1990 Remaster  Led Zeppelin
# 20411                    All My Love - 1990 Remaster  Led Zeppelin
# 21415                      Ramble On - 1990 Remaster  Led Zeppelin
# 21416                 Immigrant Song - 1990 Remaster  Led Zeppelin
# 21417  Trampled Under Foot - 2007 Remastered Version  Led Zeppelin
# 21418                               Fool in the Rain  Led Zeppelin
# 21419                      The Rover - 1993 Remaster  Led Zeppelin
# 21659                      Immigrant Song - Remaster  Led Zeppelin
# 22410                           Black Dog - Remaster  Led Zeppelin
# 22434                        Kashmir - 2012 Remaster  Led Zeppelin
# 22842                        Kashmir - 1990 Remaster  Led Zeppelin
# 22845             Stairway to Heaven - 1990 Remaster  Led Zeppelin
# 26333                             Stairway To Heaven  Led Zeppelin
# 29060             Stairway to Heaven - 1990 Remaster  Led Zeppelin
#
#        track_popularity                          track_album_name  \
# 664                  73          Led Zeppelin IV (Deluxe Edition)
# 2075                 53                           Led Zeppelin IV
# 4111                 59                           Led Zeppelin IV
# 4414                 76                           Led Zeppelin II
# 7858                 70                           Led Zeppelin II
# 8638                 76                           Led Zeppelin II
# 9043                 70                              Led Zeppelin
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   track_name           32821 non-null  object
#  1   track_artist         32821 non-null  object
#  2   track_popularity     32821 non-null  int64
#  3   track_album_name     32821 non-null  object
#  4   playlist_name        32821 non-null  object
#  5   playlist_genre       32821 non-null  object
#  6   playlist_subgenre    32821 non-null  object
#  7   danceability         32821 non-null  float64
#  8   energy               32821 non-null  float64
#  9   key                  32821 non-null  int64
#  10  loudness             32821 non-null  float64
#  11  mode                 32821 non-null  int64
#  12  speechiness          32821 non-null  float64
#  13  acousticness         32821 non-null  float64
#  14  instrumentalness     32821 non-null  float64
#  15  liveness             32821 non-null  float64
#  16  valence              32821 non-null  float64
#  17  tempo                32821 non-null  float64
#  18  duration_ms          32821 non-null  float64
#  19  album_release_year   32821 non-null  int64
#  20  album_release_month  32821 non-null  int64
# dtypes: float64(10), int64(5), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Prepare Features

# %%
features = features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 
            'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms']

# %%
scaler =  MinMaxScaler()
normalized_features = scaler.fit_transform(df[features])

# %%
print(normalized_features)
# Out:
# [[0.68769074 0.92898757 0.90909091 ... 0.15842583 0.40519128 0.30594967]
#  [0.58392675 0.72795239 0.09090909 ... 0.26841574 0.52224774 0.41054475]
#  [0.78840285 0.58492736 0.90909091 ... 0.52270434 0.45916305 0.64918939]
#  ...
#  [0.61139369 0.98999825 0.54545455 ... 0.19374369 0.53440528 0.28050252]
#  [0.85045778 0.92598705 0.18181818 ... 0.1493441  0.53448463 0.47353886]
#  [0.85757884 0.8439727  0.18181818 ... 0.73360242 0.53449716 0.54689477]]

# %% [markdown]
# ## Calculation using cosine-similarity

# %%
similarity_matrix = cosine_similarity(normalized_features)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 similarity_matrix = cosine_similarity(normalized_features)
#
# File /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File /usr/local/lib/python3.10/dist-packages/sklearn/metrics/pairwise.py:1687, in cosine_similarity(X, Y, dense_output)
#    1684 else:
#    1685     Y_normalized = normalize(Y, copy=True)
# -> 1687 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1689 return K
#
# File /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:205, in safe_sparse_dot(a, b, dense_output)
#     203         ret = np.dot(a, b)
#     204 else:
# --> 205     ret = a @ b
#     207 if (
#     208     sparse.issparse(a)
#     209     and sparse.issparse(b)
#     210     and dense_output
#     211     and hasattr(ret, "toarray")
#     212 ):
#     213     return ret.toarray()
#
# MemoryError: Unable to allocate 8.03 GiB for an array with shape (32821, 32821) and data type float64

# %% [markdown]
# ## Calculation using annoy
#
# since using cosine_similarity occured this error "MemoryError: Unable to allocate 8.03 GiB for an array with shape (32821, 32821) and data type float64"

# %%
# Set parameters
n_trees = 10
n_neighbors = 10

# Annoy Index
feature_length = normalized_features.shape[1]
annoy_index = AnnoyIndex(feature_length, 'angular')

# %%
# building annoy_index

for i, feature_vector in enumerate(normalized_features):
    annoy_index.add_item(i,feature_vector)

annoy_index.build(n_trees)
# Out:
# True

# %%
def recommend_tracks_annoy(track_name, track_artist, df, annoy_index, top_n=10):
    try:
        track_index = df[(df['track_name'] == track_name) & (df['track_artist'] == track_artist)].index[0]
        neighbor_indices = annoy_index.get_nns_by_item(track_index, top_n + 1)  # +1 to exclude the track itself
        neighbor_indices = neighbor_indices[1:]  # Exclude the track itself
        recommendations = df.iloc[neighbor_indices][['track_name', 'track_artist']]
        return recommendations
    except IndexError:
        return "Track not found in the dataset."

# %%
# Example usage
track_name = "Black Dog"
track_artist = "Led Zeppelin"
recommended_tracks = recommend_tracks_annoy(track_name, track_artist, df, annoy_index)
print(recommended_tracks)
# Out:
# Track not found in the dataset.
